# %% [markdown]
# 1) Introduction/Business Problem
# Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem:
#
#
# Search the best local in Rome city through API foursquare

# %% [markdown]
# 2) Data
# Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data:
#
# After download the relevant place i will analyze the best rating of local

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ZHI0OEATLLL1CM1Z3BKIBHNVSQAAGBXTMKU1XCF3XJGEKTRQ' # your Foursquare ID
CLIENT_SECRET = 'EQEQMWAJI2CA0QQE55QMLOXYJM45G1XD2F2XL2UHAAAN04DY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZHI0OEATLLL1CM1Z3BKIBHNVSQAAGBXTMKU1XCF3XJGEKTRQ
# CLIENT_SECRET:EQEQMWAJI2CA0QQE55QMLOXYJM45G1XD2F2XL2UHAAAN04DY

# %%
address = 'Piazza di Pietra, 35, Roma'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 41.8999682 12.4791901

# %%
search_query = 'Italian'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZHI0OEATLLL1CM1Z3BKIBHNVSQAAGBXTMKU1XCF3XJGEKTRQ&client_secret=EQEQMWAJI2CA0QQE55QMLOXYJM45G1XD2F2XL2UHAAAN04DY&ll=41.8999682,12.4791901&v=20180604&query=Italian&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fc9340e4e19e45ea53233a7'},
#  'response': {'venues': [{'id': '4bfd863d8992a593e13facb0',
#     'name': 'Repubblica Italiana',
#     'location': {'lat': 41.90068661260466,
#      'lng': 12.486011086959934,
#      'distance': 570,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '530e33ccbcbc57f1066bbff7',
#       'name': 'Country',
#       'pluralName': 'Countries',
#       'shortName': 'Country',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5f1df573a5f44255f15ef89c',
#     'name': 'Italian Jewelry Shop',
#     'location': {'address': 'Corso Italia, 100',
#      'lat': 41.9103033,
#      'lng': 12.5002708,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.9103033,
#        'lng': 12.5002708}],
#      'distance': 2091,
#      'postalCode': '58015',
#      'cc': 'IT',
#      'city': 'Orbetello',
#      'country': 'Italia',
#      'formattedAddress': ['Corso Italia, 100', '58015 Orbetello', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '581140203'},
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5ae0385ffd16bb599c9ef995',
#     'name': 'italian cooking classes in rome',
#     'location': {'address': 'Via in Arcione 98',
#      'lat': 41.9016548,
#      'lng': 12.485171100000002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.9016548,
#        'lng': 12.485171100000002}],
#      'distance': 529,
#      'postalCode': '00187',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via in Arcione 98', '00187 Roma Lazio', 'Italia']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a45',
#       'name': 'Preschool',
#       'pluralName': 'Preschools',
#       'shortName': 'Preschool',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '488974300'},
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5bed4702b23dfa002bb51a87',
#     'name': 'italian cooking classes in rome',
#     'location': {'address': 'Via in arcione 98',
#      'lat': 41.90166536316241,
#      'lng': 12.485216796349048,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.90166536316241,
#        'lng': 12.485216796349048}],
#      'distance': 533,
#      'postalCode': '00187',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via in arcione 98', '00187 Roma Lazio', 'Italia']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec200',
#       'name': 'Cooking School',
#       'pluralName': 'Cooking Schools',
#       'shortName': 'Cooking School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5824730432eb3d54fd6d3f01',
#     'name': 'Italian Bistrot Piazza',
#     'location': {'lat': 41.90587352971513,
#      'lng': 12.4809195006961,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.90587352971513,
#        'lng': 12.4809195006961}],
#      'distance': 672,
#      'postalCode': '00187',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['00187 Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4ecd86d40e01f1a87c8c8ee4',
#     'name': 'Very Italian Pizza',
#     'location': {'lat': 41.89708722835026,
#      'lng': 12.471952586916364,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89708722835026,
#        'lng': 12.471952586916364}],
#      'distance': 680,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4c3f7633d7fad13a828b04da',
#     'name': 'Italian Home',
#     'location': {'address': 'Piazza delle cinque scole 23',
#      'lat': 41.892783,
#      'lng': 12.476544,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.892783,
#        'lng': 12.476544}],
#      'distance': 829,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza delle cinque scole 23',
#       'Roma Lazio',
#       'Italia']},
#     'categories': [],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4fcc7499e4b06fcf03aa208d',
#     'name': 'Italian Details',
#     'location': {'address': 'Via Crescenzio 19',
#      'lat': 41.898374764887095,
#      'lng': 12.465894556880944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.898374764887095,
#        'lng': 12.465894556880944}],
#      'distance': 1115,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Crescenzio 19', 'Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '53caaf12498e5a9dfe6488b5',
#     'name': 'Quality Italian Food',
#     'location': {'lat': 41.903112,
#      'lng': 12.48643,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.903112,
#        'lng': 12.48643}],
#      'distance': 694,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '50aa9e744b90af0d42d5de0e',
#       'name': 'Health Food Store',
#       'pluralName': 'Health Food Stores',
#       'shortName': 'Health Food Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '560ab7cc498e3150de67c541',
#     'name': 'ITALIAN JOB STUDIO HQ',
#     'location': {'address': 'Piazza Della Suburra 11',
#      'lat': 41.89119,
#      'lng': 12.487706,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89119,
#        'lng': 12.487706}],
#      'distance': 1205,
#      'postalCode': '00184',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza Della Suburra 11',
#       '00184 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a35',
#       'name': 'Club House',
#       'pluralName': 'Club Houses',
#       'shortName': 'Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '53ed1bf3498edee2a79ed984',
#     'name': 'mio italian sweety',
#     'location': {'address': 'Via Flaminia Vecchia, 492 A',
#      'lat': 41.89558151920326,
#      'lng': 12.472350121421298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89558151920326,
#        'lng': 12.472350121421298}],
#      'distance': 748,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Flaminia Vecchia, 492 A',
#       'Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '509e9719e4b051548e12aba1',
#     'name': 'Italian Casa de Kirch',
#     'location': {'lat': 41.889226,
#      'lng': 12.468158,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.889226,
#        'lng': 12.468158}],
#      'distance': 1505,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '51b9f03c498ec64053c5883a',
#     'name': 'Kappa Language School - Italian Language School in Rome',
#     'location': {'address': 'Via del Boschetto, 32',
#      'lat': 41.897863794633814,
#      'lng': 12.49033020990972,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.897863794633814,
#        'lng': 12.49033020990972}],
#      'distance': 952,
#      'postalCode': '00184',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via del Boschetto, 32',
#       '00184 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d13b941735',
#       'name': 'School',
#       'pluralName': 'Schools',
#       'shortName': 'School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '95640780'},
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4e451315a809d4ed1bc3da9b',
#     'name': 'Italian Food',
#     'location': {'address': 'Via volturno',
#      'lat': 41.90511824220773,
#      'lng': 12.498937689926898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.90511824220773,
#        'lng': 12.498937689926898}],
#      'distance': 1733,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via volturno', 'Roma Lazio', 'Italia']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4eaeeb4c8b8181aef8b7e909',
#     'name': 'Italian Smokepit',
#     'location': {'lat': 41.881269945679605,
#      'lng': 12.486415897387705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.881269945679605,
#        'lng': 12.486415897387705}],
#      'distance': 2165,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4da421e7c6e96ea8793bf65d',
#     'name': 'Societa italiana Brevetti',
#     'location': {'address': 'Piazza di Pietra 38',
#      'lat': 41.900389,
#      'lng': 12.479157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.900389,
#        'lng': 12.479157}],
#      'distance': 46,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Piazza di Pietra 38', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '553b84d5498e4f8a02d284c9',
#     'name': 'Gianni & Cesare Italian Cooking Class',
#     'location': {'lat': 41.89933,
#      'lng': 12.461777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.89933,
#        'lng': 12.461777}],
#      'distance': 1444,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '508b9892e4b032d8be2409ab',
#     'name': 'Italian Garden',
#     'location': {'lat': 41.902117334528036,
#      'lng': 12.44875431060791,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.902117334528036,
#        'lng': 12.44875431060791}],
#      'distance': 2533,
#      'cc': 'IT',
#      'city': 'Vatican City',
#      'country': 'Italia',
#      'formattedAddress': ['Vatican City', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5f258b3104b0360c669986ad',
#     'name': 'Szifiami Italian Bistrot',
#     'location': {'lat': 41.904083,
#      'lng': 12.4610405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.904083,
#        'lng': 12.4610405}],
#      'distance': 1571,
#      'postalCode': '00193',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['00193 Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '532f3250498e457b4afbeac5',
#     'name': 'Italian Stail @ 7cl',
#     'location': {'address': 'via degli Aurunci 35',
#      'lat': 41.896253,
#      'lng': 12.514613,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.896253,
#        'lng': 12.514613}],
#      'distance': 2964,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['via degli Aurunci 35', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '5799f48e498e2f1b92f7b2e0',
#     'name': 'Cruciani - Italian luxury pop',
#     'location': {'address': 'Lato Via Marsala',
#      'lat': 41.901663,
#      'lng': 12.502075,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.901663,
#        'lng': 12.502075}],
#      'distance': 1905,
#      'postalCode': '00185',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Lato Via Marsala', '00185 Roma Lazio', 'Italia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b2b',
#       'name': 'Leather Goods Store',
#       'pluralName': 'Leather Goods Stores',
#       'shortName': 'Leather Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '56da08e6498e2749a5a5fe19',
#     'name': 'Italian Deja vu',
#     'location': {'lat': 41.896576684513676,
#      'lng': 12.439952820528596,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.896576684513676,
#        'lng': 12.439952820528596}],
#      'distance': 3272,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '53de7220498ec77445da134b',
#     'name': 'Italian Stail al Fare Scalo',
#     'location': {'lat': 41.897211,
#      'lng': 12.520214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.897211,
#        'lng': 12.520214}],
#      'distance': 3412,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'shortName': 'Entertainment',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '584ab868d772f952a5778e39',
#     'name': 'Indian Italian Halal Restaurant',
#     'location': {'address': '6/6A',
#      'crossStreet': 'Via Candia',
#      'lat': 41.908504,
#      'lng': 12.454989,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.908504,
#        'lng': 12.454989}],
#      'distance': 2218,
#      'postalCode': '00192',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['6/6A (Via Candia)', '00192 Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '51e14cca498e61dccb5fb137',
#     'name': 'Italian Home',
#     'location': {'lat': 41.891137,
#      'lng': 12.521769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.891137,
#        'lng': 12.521769}],
#      'distance': 3662,
#      'cc': 'IT',
#      'country': 'Italia',
#      'formattedAddress': ['Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1de941735',
#       'name': 'Vineyard',
#       'pluralName': 'Vineyards',
#       'shortName': 'Vineyard',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/vineyard_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '591dc3ecbcbf7a5f86916395',
#     'name': 'Remo Italian restaurant Pizzeria',
#     'location': {'address': '18 Via degli Scipioni',
#      'lat': 41.907978,
#      'lng': 12.456052,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.907978,
#        'lng': 12.456052}],
#      'distance': 2114,
#      'postalCode': '00192',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['18 Via degli Scipioni',
#       '00192 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '582a076b8edd3a34fb616ce0',
#     'name': 'Alimentari Kitchen Italian Food',
#     'location': {'address': 'Via Merulana 179',
#      'lat': 41.890615,
#      'lng': 12.50253,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.890615,
#        'lng': 12.50253}],
#      'distance': 2196,
#      'postalCode': '00185',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Merulana 179', '00185 Roma Lazio', 'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '52fcb867498eef9cc5eede48',
#     'name': 'Italian Chef Academy',
#     'location': {'address': 'Via Della Cammillucia',
#      'lat': 41.93132243704698,
#      'lng': 12.44611582520322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.93132243704698,
#        'lng': 12.44611582520322}],
#      'distance': 4437,
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Della Cammillucia', 'Roma Lazio', 'Italia']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a46',
#       'name': 'Private School',
#       'pluralName': 'Private Schools',
#       'shortName': 'Private School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '51d2f717498ea3694f92e2c5',
#     'name': 'Roman And Italian',
#     'location': {'address': 'Via Emanuele Filiberto, 161',
#      'lat': 41.890197908274956,
#      'lng': 12.506694498109042,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.890197908274956,
#        'lng': 12.506694498109042}],
#      'distance': 2525,
#      'postalCode': '00185',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Emanuele Filiberto, 161',
#       '00185 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'shortName': 'B & B',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False},
#    {'id': '4eb90f1cf790d87d043c382b',
#     'name': 'Italian Dog',
#     'location': {'address': 'Via Appia Pignatelli, 173, 00178 Roma',
#      'lat': 41.87147670239354,
#      'lng': 12.528438768031577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87147670239354,
#        'lng': 12.528438768031577}],
#      'distance': 5168,
#      'postalCode': '00178',
#      'cc': 'IT',
#      'city': 'Roma',
#      'state': 'Lazio',
#      'country': 'Italia',
#      'formattedAddress': ['Via Appia Pignatelli, 173, 00178 Roma',
#       '00178 Roma Lazio',
#       'Italia']},
#     'categories': [{'id': '4e52d2d203646f7c19daa8ae',
#       'name': 'Animal Shelter',
#       'pluralName': 'Animal Shelters',
#       'shortName': 'Animal Shelter',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/animalshelter_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607021582',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  4bfd863d8992a593e13facb0              Repubblica Italiana
# 1  5f1df573a5f44255f15ef89c             Italian Jewelry Shop
# 2  5ae0385ffd16bb599c9ef995  italian cooking classes in rome
# 3  5bed4702b23dfa002bb51a87  italian cooking classes in rome
# 4  5824730432eb3d54fd6d3f01           Italian Bistrot Piazza
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '530e33ccbcbc57f1066bbff7', 'name': 'C...  v-1607021582    False
# 1  [{'id': '4bf58dd8d48988d111951735', 'name': 'J...  v-1607021582    False
# 2  [{'id': '52e81612bcbc57f1066b7a45', 'name': 'P...  v-1607021582    False
# 3  [{'id': '58daa1558bbb0b01f18ec200', 'name': 'C...  v-1607021582    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1607021582    False
#
#    location.lat  location.lng  location.distance location.cc location.country  \
# 0     41.900687     12.486011                570          IT           Italia
# 1     41.910303     12.500271               2091          IT           Italia
# 2     41.901655     12.485171                529          IT           Italia
# 3     41.901665     12.485217                533          IT           Italia
# 4     41.905874     12.480920                672          IT           Italia
#
#                        location.formattedAddress   location.address  \
# 0                                       [Italia]                NaN
# 1   [Corso Italia, 100, 58015 Orbetello, Italia]  Corso Italia, 100
# 2  [Via in Arcione 98, 00187 Roma Lazio, Italia]  Via in Arcione 98
# 3  [Via in arcione 98, 00187 Roma Lazio, Italia]  Via in arcione 98
# 4                     [00187 Roma Lazio, Italia]                NaN
#
#                              location.labeledLatLngs location.postalCode  \
# 0                                                NaN                 NaN
# 1  [{'label': 'display', 'lat': 41.9103033, 'lng'...               58015
# 2  [{'label': 'display', 'lat': 41.9016548, 'lng'...               00187
# 3  [{'label': 'display', 'lat': 41.90166536316241...               00187
# 4  [{'label': 'display', 'lat': 41.90587352971513...               00187
#
#   location.city venuePage.id location.state location.crossStreet
# 0           NaN          NaN            NaN                  NaN
# 1     Orbetello    581140203            NaN                  NaN
# 2          Roma    488974300          Lazio                  NaN
# 3          Roma          NaN          Lazio                  NaN
# 4          Roma          NaN          Lazio                  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                                 Repubblica Italiana
# 1                                Italian Jewelry Shop
# 2                     italian cooking classes in rome
# 3                     italian cooking classes in rome
# 4                              Italian Bistrot Piazza
# 5                                  Very Italian Pizza
# 6                                        Italian Home
# 7                                     Italian Details
# 8                                Quality Italian Food
# 9                               ITALIAN JOB STUDIO HQ
# 10                                 mio italian sweety
# 11                              Italian Casa de Kirch
# 12  Kappa Language School - Italian Language Schoo...
# 13                                       Italian Food
# 14                                   Italian Smokepit
# 15                          Societa italiana Brevetti
# 16              Gianni & Cesare Italian Cooking Class
# 17                                     Italian Garden
# 18                           Szifiami Italian Bistrot
# 19                                Italian Stail @ 7cl
# 20                      Cruciani - Italian luxury pop
# 21                                    Italian Deja vu
# 22                        Italian Stail al Fare Scalo
# 23                    Indian Italian Halal Restaurant
# 24                                       Italian Home
# 25                   Remo Italian restaurant Pizzeria
# 26                    Alimentari Kitchen Italian Food
# 27                               Italian Chef Academy
# 28                                  Roman And Italian
# 29                                        Italian Dog
#
#                                   categories        lat        lng  distance  \
# 0                                    Country  41.900687  12.486011       570
# 1                              Jewelry Store  41.910303  12.500271      2091
# 2                                  Preschool  41.901655  12.485171       529
# 3                             Cooking School  41.901665  12.485217       533
# 4                         Italian Restaurant  41.905874  12.480920       672
# 5                                Pizza Place  41.897087  12.471953       680
# 6                                       None  41.892783  12.476544       829
# 7                                     Office  41.898375  12.465895      1115
# 8                          Health Food Store  41.903112  12.486430       694
# 9                                 Club House  41.891190  12.487706      1205
# 10                              Dessert Shop  41.895582  12.472350       748
# 11  Residential Building (Apartment / Condo)  41.889226  12.468158      1505
# 12                                    School  41.897864  12.490330       952
# 13                                      Food  41.905118  12.498938      1733
# 14                                 Nightclub  41.881270  12.486416      2165
# 15                                    Office  41.900389  12.479157        46
# 16                        Italian Restaurant  41.899330  12.461777      1444
# 17                                    Garden  41.902117  12.448754      2533
# 18                                      Café  41.904083  12.461040      1571
# 19                                 Nightclub  41.896253  12.514613      2964
# 20                       Leather Goods Store  41.901663  12.502075      1905
# 21  Residential Building (Apartment / Condo)  41.896577  12.439953      3272
# 22                     General Entertainment  41.897211  12.520214      3412
# 23                        Italian Restaurant  41.908504  12.454989      2218
# 24                                  Vineyard  41.891137  12.521769      3662
# 25                        Italian Restaurant  41.907978  12.456052      2114
# 26                        Italian Restaurant  41.890615  12.502530      2196
# 27                            Private School  41.931322  12.446116      4437
# 28                           Bed & Breakfast  41.890198  12.506694      2525
# 29                            Animal Shelter  41.871477  12.528439      5168
#
#     cc country                                   formattedAddress  \
# 0   IT  Italia                                           [Italia]
# 1   IT  Italia       [Corso Italia, 100, 58015 Orbetello, Italia]
# 2   IT  Italia      [Via in Arcione 98, 00187 Roma Lazio, Italia]
# 3   IT  Italia      [Via in arcione 98, 00187 Roma Lazio, Italia]
# 4   IT  Italia                         [00187 Roma Lazio, Italia]
# 5   IT  Italia                               [Roma Lazio, Italia]
# 6   IT  Italia  [Piazza delle cinque scole 23, Roma Lazio, Ita...
# 7   IT  Italia            [Via Crescenzio 19, Roma Lazio, Italia]
# 8   IT  Italia                                           [Italia]
# 9   IT  Italia  [Piazza Della Suburra 11, 00184 Roma Lazio, It...
# 10  IT  Italia  [Via Flaminia Vecchia, 492 A, Roma Lazio, Italia]
# 11  IT  Italia                                           [Italia]
# 12  IT  Italia  [Via del Boschetto, 32, 00184 Roma Lazio, Italia]
# 13  IT  Italia                 [Via volturno, Roma Lazio, Italia]
# 14  IT  Italia                                           [Italia]
# 15  IT  Italia                      [Piazza di Pietra 38, Italia]
# 16  IT  Italia                                           [Italia]
# 17  IT  Italia                             [Vatican City, Italia]
# 18  IT  Italia                         [00193 Roma Lazio, Italia]
# 19  IT  Italia                     [via degli Aurunci 35, Italia]
# 20  IT  Italia       [Lato Via Marsala, 00185 Roma Lazio, Italia]
# 21  IT  Italia                                           [Italia]
# 22  IT  Italia                               [Roma Lazio, Italia]
# 23  IT  Italia      [6/6A (Via Candia), 00192 Roma Lazio, Italia]
# 24  IT  Italia                                           [Italia]
# 25  IT  Italia  [18 Via degli Scipioni, 00192 Roma Lazio, Italia]
# 26  IT  Italia       [Via Merulana 179, 00185 Roma Lazio, Italia]
# 27  IT  Italia        [Via Della Cammillucia, Roma Lazio, Italia]
# 28  IT  Italia  [Via Emanuele Filiberto, 161, 00185 Roma Lazio...
# 29  IT  Italia  [Via Appia Pignatelli, 173, 00178 Roma, 00178 ...
#
#                                   address  \
# 0                                     NaN
# 1                       Corso Italia, 100
# 2                       Via in Arcione 98
# 3                       Via in arcione 98
# 4                                     NaN
# 5                                     NaN
# 6            Piazza delle cinque scole 23
# 7                       Via Crescenzio 19
# 8                                     NaN
# 9                 Piazza Della Suburra 11
# 10            Via Flaminia Vecchia, 492 A
# 11                                    NaN
# 12                  Via del Boschetto, 32
# 13                           Via volturno
# 14                                    NaN
# 15                    Piazza di Pietra 38
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                   via degli Aurunci 35
# 20                       Lato Via Marsala
# 21                                    NaN
# 22                                    NaN
# 23                                   6/6A
# 24                                    NaN
# 25                  18 Via degli Scipioni
# 26                       Via Merulana 179
# 27                  Via Della Cammillucia
# 28            Via Emanuele Filiberto, 161
# 29  Via Appia Pignatelli, 173, 00178 Roma
#
#                                        labeledLatLngs postalCode  \
# 0                                                 NaN        NaN
# 1   [{'label': 'display', 'lat': 41.9103033, 'lng'...      58015
# 2   [{'label': 'display', 'lat': 41.9016548, 'lng'...      00187
# 3   [{'label': 'display', 'lat': 41.90166536316241...      00187
# 4   [{'label': 'display', 'lat': 41.90587352971513...      00187
# 5   [{'label': 'display', 'lat': 41.89708722835026...        NaN
# 6   [{'label': 'display', 'lat': 41.892783, 'lng':...        NaN
# 7   [{'label': 'display', 'lat': 41.89837476488709...        NaN
# 8   [{'label': 'display', 'lat': 41.903112, 'lng':...        NaN
# 9   [{'label': 'display', 'lat': 41.89119, 'lng': ...      00184
# 10  [{'label': 'display', 'lat': 41.89558151920326...        NaN
# 11  [{'label': 'display', 'lat': 41.889226, 'lng':...        NaN
# 12  [{'label': 'display', 'lat': 41.89786379463381...      00184
# 13  [{'label': 'display', 'lat': 41.90511824220773...        NaN
# 14  [{'label': 'display', 'lat': 41.88126994567960...        NaN
# 15  [{'label': 'display', 'lat': 41.900389, 'lng':...        NaN
# 16  [{'label': 'display', 'lat': 41.89933, 'lng': ...        NaN
# 17  [{'label': 'display', 'lat': 41.90211733452803...        NaN
# 18  [{'label': 'display', 'lat': 41.904083, 'lng':...      00193
# 19  [{'label': 'display', 'lat': 41.896253, 'lng':...        NaN
# 20  [{'label': 'display', 'lat': 41.901663, 'lng':...      00185
# 21  [{'label': 'display', 'lat': 41.89657668451367...        NaN
# 22  [{'label': 'display', 'lat': 41.897211, 'lng':...        NaN
# 23  [{'label': 'display', 'lat': 41.908504, 'lng':...      00192
# 24  [{'label': 'display', 'lat': 41.891137, 'lng':...        NaN
# 25  [{'label': 'display', 'lat': 41.907978, 'lng':...      00192
# 26  [{'label': 'display', 'lat': 41.890615, 'lng':...      00185
# 27  [{'label': 'display', 'lat': 41.93132243704698...        NaN
# 28  [{'label': 'display', 'lat': 41.89019790827495...      00185
# 29  [{'label': 'display', 'lat': 41.87147670239354...      00178
#
#             city  state crossStreet                        id
# 0            NaN    NaN         NaN  4bfd863d8992a593e13facb0
# 1      Orbetello    NaN         NaN  5f1df573a5f44255f15ef89c
# 2           Roma  Lazio         NaN  5ae0385ffd16bb599c9ef995
# 3           Roma  Lazio         NaN  5bed4702b23dfa002bb51a87
# 4           Roma  Lazio         NaN  5824730432eb3d54fd6d3f01
# 5           Roma  Lazio         NaN  4ecd86d40e01f1a87c8c8ee4
# 6           Roma  Lazio         NaN  4c3f7633d7fad13a828b04da
# 7           Roma  Lazio         NaN  4fcc7499e4b06fcf03aa208d
# 8            NaN    NaN         NaN  53caaf12498e5a9dfe6488b5
# 9           Roma  Lazio         NaN  560ab7cc498e3150de67c541
# 10          Roma  Lazio         NaN  53ed1bf3498edee2a79ed984
# 11           NaN    NaN         NaN  509e9719e4b051548e12aba1
# 12          Roma  Lazio         NaN  51b9f03c498ec64053c5883a
# 13          Roma  Lazio         NaN  4e451315a809d4ed1bc3da9b
# 14           NaN    NaN         NaN  4eaeeb4c8b8181aef8b7e909
# 15           NaN    NaN         NaN  4da421e7c6e96ea8793bf65d
# 16           NaN    NaN         NaN  553b84d5498e4f8a02d284c9
# 17  Vatican City    NaN         NaN  508b9892e4b032d8be2409ab
# 18          Roma  Lazio         NaN  5f258b3104b0360c669986ad
# 19           NaN    NaN         NaN  532f3250498e457b4afbeac5
# 20          Roma  Lazio         NaN  5799f48e498e2f1b92f7b2e0
# 21           NaN    NaN         NaN  56da08e6498e2749a5a5fe19
# 22          Roma  Lazio         NaN  53de7220498ec77445da134b
# 23          Roma  Lazio  Via Candia  584ab868d772f952a5778e39
# 24           NaN    NaN         NaN  51e14cca498e61dccb5fb137
# 25          Roma  Lazio         NaN  591dc3ecbcbf7a5f86916395
# 26          Roma  Lazio         NaN  582a076b8edd3a34fb616ce0
# 27          Roma  Lazio         NaN  52fcb867498eef9cc5eede48
# 28          Roma  Lazio         NaN  51d2f717498ea3694f92e2c5
# 29          Roma  Lazio         NaN  4eb90f1cf790d87d043c382b

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
